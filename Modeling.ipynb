# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action = 'ignore')
warnings.filterwarnings('ignore')

# 시각화를 위한 라이브러리 호출
import matplotlib
from matplotlib import font_manager, rc
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import seaborn as sns

# 폰트 경로 지정
# font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'



# 폰트 적용
# plt.rc('font', family=font_prop.get_name())

# 나눔바른고딕 폰트 경로 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# 폰트 속성 설정
font_prop = fm.FontProperties(fname=font_path)
# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %%
from google.colab import drive

drive.mount('/content/drive')
# 구글 클라우드 데이터 위치
DATA_DIR = '/content/drive/My Drive/Colab Notebooks/기경데분'
# Out:
# Mounted at /content/drive

# %%
house_df = pd.read_csv(f'{DATA_DIR}/house_base.csv')

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504923 entries, 0 to 504922
# Data columns (total 40 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   자치구명       504923 non-null  object
#  1   법정동코드      504923 non-null  int64
#  2   지번구분코드     504923 non-null  int64
#  3   본번         504923 non-null  int64
#  4   부번         504923 non-null  int64
#  5   층          504923 non-null  int64
#  6   계약일        504923 non-null  int64
#  7   임대면적       504923 non-null  float64
#  8   보증금(만원)    504923 non-null  int64
#  9   임대료(만원)    504923 non-null  int64
#  10  건축년도       504923 non-null  int64
#  11  건물용도       504923 non-null  int64
#  12  연도         504923 non-null  int64
#  13  월          504923 non-null  int64
#  14  일          504923 non-null  int64
#  15  자치구명_강남구   504923 non-null  int64
#  16  자치구명_강동구   504923 non-null  int64
#  17  자치구명_강북구   504923 non-null  int64
#  18  자치구명_강서구   504923 non-null  int64
# ...

# %%
data = house_df[['본번', '층', '임대면적', '보증금(만원)', '건물용도', '연도', '일', '자치구명_강남구', '자치구명_강동구', '자치구명_강북구', '자치구명_강서구',
       '자치구명_관악구', '자치구명_광진구', '자치구명_구로구', '자치구명_금천구', '자치구명_노원구', '자치구명_도봉구',
       '자치구명_동대문구', '자치구명_동작구', '자치구명_마포구', '자치구명_서대문구', '자치구명_서초구',
       '자치구명_성동구', '자치구명_성북구', '자치구명_송파구', '자치구명_양천구', '자치구명_영등포구', '자치구명_용산구',
       '자치구명_은평구', '자치구명_종로구', '자치구명_중구', '자치구명_중랑구', '임대료(만원)']]

data['교차항_임대면적X보증금'] = data['임대면적'] * data['보증금(만원)']

# %%
data.describe()
# Out:
#                   본번              층           임대면적        보증금(만원)  \
# count  504923.000000  504923.000000  504923.000000  504923.000000
# mean      323.539268     391.041559      44.161623    9888.806543
# std       482.445286     482.841796      27.529566   18226.589410
# min         0.000000      -3.000000       3.400000       0.000000
# 25%         0.000000       5.000000      23.040000    1000.000000
# 50%        91.000000      12.000000      36.850000    3000.000000
# 75%       535.000000     999.000000      59.580000   10000.000000
# max      4972.000000     999.000000     317.360000  500000.000000
#
#                 건물용도             연도              일       자치구명_강남구  \
# count  504923.000000  504923.000000  504923.000000  504923.000000
# mean        2.930912    2021.416903      15.787635       0.067400
# std         0.978563       0.903551       8.599293       0.250714
# min         1.000000    2011.000000       1.000000       0.000000
# ...

# %%
x = data[['본번', '층', '임대면적', '보증금(만원)','교차항_임대면적X보증금', '건물용도', '연도', '일', '자치구명_강남구', '자치구명_강동구', '자치구명_강북구', '자치구명_강서구',
       '자치구명_관악구', '자치구명_광진구', '자치구명_구로구', '자치구명_금천구', '자치구명_노원구', '자치구명_도봉구',
       '자치구명_동대문구', '자치구명_동작구', '자치구명_마포구', '자치구명_서대문구', '자치구명_서초구',
       '자치구명_성동구', '자치구명_성북구', '자치구명_송파구', '자치구명_양천구', '자치구명_영등포구', '자치구명_용산구',
       '자치구명_은평구', '자치구명_종로구', '자치구명_중구', '자치구명_중랑구']]
y = data['임대료(만원)']

# %%
from sklearn.model_selection import train_test_split

# 독립 변수와 종속 변수를 나누기 위한 train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# train-test split 결과 확인
print("학습 데이터 (x_train) 크기:", x_train.shape)
print("테스트 데이터 (x_test) 크기:", x_test.shape)
print("학습 데이터 (y_train) 크기:", y_train.shape)
print("테스트 데이터 (y_test) 크기:", y_test.shape)
# Out:
# 학습 데이터 (x_train) 크기: (403938, 33)
# 테스트 데이터 (x_test) 크기: (100985, 33)
# 학습 데이터 (y_train) 크기: (403938,)
# 테스트 데이터 (y_test) 크기: (100985,)

# %%
train_reg = x_train[['본번', '층', '임대면적', '보증금(만원)', '교차항_임대면적X보증금', '자치구명_강남구','자치구명_강동구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
test_reg = x_test[['본번', '층', '임대면적', '보증금(만원)', '교차항_임대면적X보증금','자치구명_강남구','자치구명_강동구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]

x_train.drop(['본번', '층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','자치구명_강남구','자치구명_강동구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구'], axis=1, inplace=True)
x_test.drop(['본번', '층', '임대면적', '보증금(만원)', '교차항_임대면적X보증금','자치구명_강남구','자치구명_강동구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(train_reg)
train_scaled = scaler.transform(train_reg)
train_df_scaled = pd.DataFrame(data = train_scaled, columns = train_reg.columns)
test_scaled = scaler.transform(test_reg)
test_df_scaled = pd.DataFrame(data = test_scaled, columns = test_reg.columns)

# %%
x_train.reset_index(drop=True, inplace=True)
train = pd.concat([train_df_scaled, x_train], axis=1)
x_test.reset_index(drop=True, inplace=True)
test = pd.concat([test_df_scaled, x_test], axis=1)


y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
y_train.describe()
# Out:
#              임대료(만원)
# count  403938.000000
# mean       63.747682
# std        68.296041
# min         0.000000
# 25%        32.000000
# 50%        50.000000
# 75%        70.000000
# max      3850.000000

# %%
y_test.describe()
# Out:
#              임대료(만원)
# count  100985.000000
# mean       63.583096
# std        67.951847
# min         0.000000
# 25%        32.000000
# 50%        50.000000
# 75%        70.000000
# max      4000.000000

# %% [markdown]
# # 강남구 분석

# %%
x_train_강남구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_강남구 = y_train

x_test_강남구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_강남구 = y_test

# %%
import statsmodels.api as sm

# x_train_강남구 = sm.add_constant(x_train_강남구)
model_강남 = sm.OLS(y_train_강남구, x_train_강남구)
results_강남 = model_강남.fit()
print(results_강남.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:50:18   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_강남구 = results_강남.predict(x_test_강남구)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error

origin = np.array(y_test_강남구)
pred = np.array(y_pred_강남구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.48895314898675
# MSE :  2991.790737826961
# RMSE :  54.69726444555487
# R2 Score :  0.3520626959122023

# %% [markdown]
# # 강동구 분석

# %%
x_train_강동구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강남구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_강동구 = y_train

x_test_강동구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강남구','자치구명_강북구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_강동구 = y_test

# %%
import statsmodels.api as sm

model_강동 = sm.OLS(y_train_강동구, x_train_강동구)
results_강동 = model_강동.fit()
print(results_강동.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:50:33   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_강동구 = results_강동.predict(x_test_강동구)

# %%
origin = np.array(y_test_강동구)
pred = np.array(y_pred_강동구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.48895314898683
# MSE :  2991.7907378269592
# RMSE :  54.69726444555486
# R2 Score :  0.35206269591220263

# %% [markdown]
# # 강북구 분석

# %%
x_train_강북구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강남구','자치구명_강동구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_강북구 = y_train

x_test_강북구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강남구','자치구명_강동구',
                   '자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_강북구 = y_test

# %%
import statsmodels.api as sm

model_강북 = sm.OLS(y_train_강북구, x_train_강북구)
results_강북 = model_강북.fit()
print(results_강북.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:50:47   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_강북구 = results_강북.predict(x_test_강북구)

# %%
origin = np.array(y_test_강북구)
pred = np.array(y_pred_강북구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986745
# MSE :  2991.7907378269592
# RMSE :  54.69726444555486
# R2 Score :  0.35206269591220263

# %% [markdown]
# # 강서구 분석

# %%
x_train_강서구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_강서구 = y_train

x_test_강서구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_강서구 = y_test

# %%
import statsmodels.api as sm

model_강서 = sm.OLS(y_train_강서구, x_train_강서구)
results_강서 = model_강서.fit()
print(results_강서.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:50:57   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_강서구 = results_강서.predict(x_test_강서구)

# %%
origin = np.array(y_test_강서구)
pred = np.array(y_pred_강서구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986777
# MSE :  2991.790737826958
# RMSE :  54.69726444555484
# R2 Score :  0.35206269591220285

# %% [markdown]
# # 관악구 분석

# %%
x_train_관악구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_관악구 = y_train

x_test_관악구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_광진구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_관악구 = y_test

# %%
import statsmodels.api as sm

model_관악 = sm.OLS(y_train_관악구, x_train_관악구)
results_관악 = model_관악.fit()
print(results_관악.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:51:11   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_관악구 = results_관악.predict(x_test_관악구)

# %%
origin = np.array(y_test_관악구)
pred = np.array(y_pred_관악구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986635
# MSE :  2991.7907378269597
# RMSE :  54.69726444555486
# R2 Score :  0.3520626959122025

# %% [markdown]
# # 광진구 분석

# %%
x_train_광진구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_광진구 = y_train

x_test_광진구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_구로구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_광진구 = y_test

# %%
import statsmodels.api as sm

model_광진 = sm.OLS(y_train_광진구, x_train_광진구)
results_광진 = model_광진.fit()
print(results_광진.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        11:57:41   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_광진구 = results_광진.predict(x_test_광진구)

# %%
origin = np.array(y_test_광진구)
pred = np.array(y_pred_광진구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.550171244152338
# MSE :  2992.4173721210386
# RMSE :  54.70299235070271
# R2 Score :  0.3519269846373393

# %% [markdown]
# # 구로구 해석

# %%
x_train_구로구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_구로구 = y_train

x_test_구로구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_금천구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_구로구 = y_test

# %%
import statsmodels.api as sm

model_구로 = sm.OLS(y_train_구로구, x_train_구로구)
results_구로 = model_구로.fit()
print(results_구로.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:00:07   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_구로구 = results_구로.predict(x_test_구로구)

# %%
origin = np.array(y_test_구로구)
pred = np.array(y_pred_구로구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.55203081105542
# MSE :  2992.498610920957
# RMSE :  54.70373489005076
# R2 Score :  0.3519093906096752

# %% [markdown]
# # 금천구 분석

# %%
x_train_금천구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_금천구 = y_train

x_test_금천구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_노원구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_금천구 = y_test

# %%
import statsmodels.api as sm

model_금천 = sm.OLS(y_train_금천구, x_train_금천구)
results_금천 = model_금천.fit()
print(results_금천.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:02:43   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_금천구 = results_금천.predict(x_test_금천구)

# %%
origin = np.array(y_test_금천구)
pred = np.array(y_pred_금천구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.55111352156741
# MSE :  2992.454805828285
# RMSE :  54.70333450374196
# R2 Score :  0.35191887755449813

# %% [markdown]
# # 노원구 분석

# %%
x_train_노원구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_노원구 = y_train

x_test_노원구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_노원구 = y_test

# %%
import statsmodels.api as sm

model_노원 = sm.OLS(y_train_노원구, x_train_노원구)
results_노원 = model_노원.fit()
print(results_노원.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:03:54   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_노원구 = results_노원.predict(x_test_노원구)

# %%
origin = np.array(y_test_노원구)
pred = np.array(y_pred_노원구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.552226411279232
# MSE :  2992.508557387485
# RMSE :  54.70382580210899
# R2 Score :  0.3519072364861847

# %% [markdown]
# # 도봉구 분석

# %%
x_train_도봉구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_도봉구 = y_train

x_test_도봉구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_도봉구 = y_test

# %%
import statsmodels.api as sm

model_도봉 = sm.OLS(y_train_도봉구, x_train_도봉구)
results_도봉 = model_도봉.fit()
print(results_도봉.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:08:00   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_도봉구 = results_도봉.predict(x_test_도봉구)

# %%
origin = np.array(y_test_도봉구)
pred = np.array(y_pred_도봉구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.552066738296624
# MSE :  2992.5004160110802
# RMSE :  54.70375138883146
# R2 Score :  0.35190899967817957

# %% [markdown]
# # 동대문구 분석

# %%
x_train_동대문구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_동대문구 = y_train

x_test_동대문구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동작구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_동대문구 = y_test

# %%
import statsmodels.api as sm

model_동대문 = sm.OLS(y_train_동대문구, x_train_동대문구)
results_동대문 = model_동대문.fit()
print(results_동대문.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:52:34   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_동대문구 = results_동대문.predict(x_test_동대문구)

# %%
origin = np.array(y_test_동대문구)
pred = np.array(y_pred_동대문구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986788
# MSE :  2991.790737826959
# RMSE :  54.69726444555485
# R2 Score :  0.35206269591220274

# %% [markdown]
# # 동작구 분석

# %%
x_train_동작구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_동작구 = y_train

x_test_동작구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_마포구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_동작구 = y_test

# %%
import statsmodels.api as sm

model_동작 = sm.OLS(y_train_동작구, x_train_동작구)
results_동작 = model_동작.fit()
print(results_동작.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:54:15   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_동작구 = results_동작.predict(x_test_동작구)

# %%
origin = np.array(y_test_동작구)
pred = np.array(y_pred_동작구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986813
# MSE :  2991.7907378269597
# RMSE :  54.69726444555486
# R2 Score :  0.3520626959122025

# %% [markdown]
# # 마포구 분석

# %%
x_train_마포구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_마포구 = y_train

x_test_마포구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_서대문구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_마포구 = y_test

# %%
import statsmodels.api as sm

model_마포 = sm.OLS(y_train_마포구, x_train_마포구)
results_마포 = model_마포.fit()
print(results_마포.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:55:43   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_마포구 = results_마포.predict(x_test_마포구)

# %%
origin = np.array(y_test_마포구)
pred = np.array(y_pred_마포구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986813
# MSE :  2991.7907378269597
# RMSE :  54.69726444555486
# R2 Score :  0.3520626959122025

# %% [markdown]
# # 서대문구 분석

# %%
x_train_서대문구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_서대문구 = y_train

x_test_서대문구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서초구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_서대문구 = y_test

# %%
import statsmodels.api as sm

model_서대문 = sm.OLS(y_train_서대문구, x_train_서대문구)
results_서대문 = model_서대문.fit()
print(results_서대문.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:58:47   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_서대문구 = results_서대문.predict(x_test_서대문구)

# %%
origin = np.array(y_test_서대문구)
pred = np.array(y_pred_서대문구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986777
# MSE :  2991.7907378269606
# RMSE :  54.697264445554865
# R2 Score :  0.3520626959122024

# %% [markdown]
# # 서초구 분석

# %%
x_train_서초구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_서초구 = y_train

x_test_서초구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_서초구 = y_test

# %%
import statsmodels.api as sm

model_서초 = sm.OLS(y_train_서초구, x_train_서초구)
results_서초 = model_서초.fit()
print(results_서초.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:59:57   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_서초구 = results_서초.predict(x_test_서초구)

# %%
origin = np.array(y_test_서초구)
pred = np.array(y_pred_서초구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986727
# MSE :  2991.790737826958
# RMSE :  54.69726444555484
# R2 Score :  0.35206269591220285

# %% [markdown]
# # 성동구 분석

# %%
x_train_성동구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_성동구 = y_train

x_test_성동구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_성동구 = y_test

# %%
import statsmodels.api as sm

model_성동 = sm.OLS(y_train_성동구, x_train_성동구)
results_성동 = model_성동.fit()
print(results_성동.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:01:38   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_성동구 = results_성동.predict(x_test_성동구)

# %%
origin = np.array(y_test_성동구)
pred = np.array(y_pred_성동구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986706
# MSE :  2991.790737826958
# RMSE :  54.69726444555484
# R2 Score :  0.35206269591220285

# %% [markdown]
# # 성북구 분석

# %%
x_train_성북구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_성북구 = y_train

x_test_성북구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_송파구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_성북구 = y_test

# %%
import statsmodels.api as sm

model_성북 = sm.OLS(y_train_성북구, x_train_성북구)
results_성북 = model_성북.fit()
print(results_성북.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:02:55   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_성북구 = results_성북.predict(x_test_성북구)

# %%
origin = np.array(y_test_성북구)
pred = np.array(y_pred_성북구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.48895314898679
# MSE :  2991.790737826961
# RMSE :  54.69726444555487
# R2 Score :  0.3520626959122023

# %% [markdown]
# # 송파구 분석

# %%
x_train_송파구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_송파구 = y_train

x_test_송파구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_양천구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_송파구 = y_test

# %%
import statsmodels.api as sm

model_송파 = sm.OLS(y_train_송파구, x_train_송파구)
results_송파 = model_송파.fit()
print(results_송파.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:03:57   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_송파구 = results_송파.predict(x_test_송파구)

# %%
origin = np.array(y_test_송파구)
pred = np.array(y_pred_송파구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.48895314898675
# MSE :  2991.790737826959
# RMSE :  54.69726444555485
# R2 Score :  0.35206269591220274

# %% [markdown]
# # 양천구 분석

# %%
x_train_양천구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_양천구 = y_train

x_test_양천구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_영등포구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_양천구 = y_test

# %%
import statsmodels.api as sm

model_양천 = sm.OLS(y_train_양천구, x_train_양천구)
results_양천 = model_양천.fit()
print(results_양천.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:05:05   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_양천구 = results_양천.predict(x_test_양천구)

# %%
origin = np.array(y_test_양천구)
pred = np.array(y_pred_양천구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986898
# MSE :  2991.7907378269597
# RMSE :  54.69726444555486
# R2 Score :  0.3520626959122025

# %% [markdown]
# # 영등포구 분석

# %%
x_train_영등포구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_영등포구 = y_train

x_test_영등포구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_용산구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_영등포구 = y_test

# %%
import statsmodels.api as sm

model_영등포 = sm.OLS(y_train_영등포구, x_train_영등포구)
results_영등포 = model_영등포.fit()
print(results_영등포.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:06:06   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_영등포구 = results_영등포.predict(x_test_영등포구)

# %%
origin = np.array(y_test_영등포구)
pred = np.array(y_pred_영등포구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986898
# MSE :  2991.7907378269597
# RMSE :  54.69726444555486
# R2 Score :  0.3520626959122025

# %% [markdown]
# # 용산구 분석

# %%
x_train_용산구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_용산구 = y_train

x_test_용산구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_은평구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_용산구 = y_test

# %%
import statsmodels.api as sm

model_용산 = sm.OLS(y_train_용산구, x_train_용산구)
results_용산 = model_용산.fit()
print(results_용산.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:07:12   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_용산구 = results_용산.predict(x_test_용산구)

# %%
origin = np.array(y_test_용산구)
pred = np.array(y_pred_용산구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.48895314898675
# MSE :  2991.7907378269606
# RMSE :  54.697264445554865
# R2 Score :  0.3520626959122024

# %% [markdown]
# # 은평구 분석

# %%
x_train_은평구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_train_은평구 = y_train

x_test_은평구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_종로구','자치구명_중구','자치구명_중랑구']]
y_test_은평구 = y_test

# %%
import statsmodels.api as sm

model_은평 = sm.OLS(y_train_은평구, x_train_은평구)
results_은평 = model_은평.fit()
print(results_은평.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:11:47   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_은평구 = results_은평.predict(x_test_은평구)

# %%
origin = np.array(y_test_은평구)
pred = np.array(y_pred_은평구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986813
# MSE :  2991.7907378269606
# RMSE :  54.697264445554865
# R2 Score :  0.3520626959122024

# %% [markdown]
# # 종로구 분석

# %%
x_train_종로구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_은평구','자치구명_중구','자치구명_중랑구']]
y_train_종로구 = y_train

x_test_종로구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_은평구','자치구명_중구','자치구명_중랑구']]
y_test_종로구 = y_test

# %%
import statsmodels.api as sm

model_종로 = sm.OLS(y_train_종로구, x_train_종로구)
results_종로 = model_종로.fit()
print(results_종로.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:12:20   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_종로구 = results_종로.predict(x_test_종로구)

# %%
origin = np.array(y_test_종로구)
pred = np.array(y_pred_종로구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.48895314898687
# MSE :  2991.7907378269592
# RMSE :  54.69726444555486
# R2 Score :  0.35206269591220263

# %% [markdown]
# # 중구 분석

# %%
x_train_중구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_은평구','자치구명_종로구','자치구명_중랑구']]
y_train_중구 = y_train

x_test_중구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_은평구','자치구명_종로구','자치구명_중랑구']]
y_test_중구 = y_test

# %%
import statsmodels.api as sm

model_중 = sm.OLS(y_train_중구, x_train_중구)
results_중 = model_중.fit()
print(results_중.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:09:37   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_중구 = results_중.predict(x_test_중구)

# %%
origin = np.array(y_test_중구)
pred = np.array(y_pred_중구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.488953148986685
# MSE :  2991.7907378269592
# RMSE :  54.69726444555486
# R2 Score :  0.35206269591220263

# %% [markdown]
# # 중랑구 분석

# %%
x_train_중랑구 = train[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_은평구','자치구명_종로구', '자치구명_중구']]
y_train_중랑구 = y_train

x_test_중랑구 = test[['본번','층','임대면적', '보증금(만원)', '교차항_임대면적X보증금','건물용도','연도','일','자치구명_강동구','자치구명_강북구',
                   '자치구명_강남구','자치구명_강서구','자치구명_관악구','자치구명_광진구','자치구명_구로구','자치구명_금천구',
                   '자치구명_노원구','자치구명_도봉구','자치구명_동대문구','자치구명_동작구','자치구명_마포구','자치구명_서대문구',
                   '자치구명_서초구','자치구명_성동구','자치구명_성북구','자치구명_송파구','자치구명_양천구','자치구명_영등포구',
                   '자치구명_용산구','자치구명_은평구','자치구명_종로구', '자치구명_중구']]
y_test_중랑구 = y_test

# %%
import statsmodels.api as sm

model_중랑 = sm.OLS(y_train_중랑구, x_train_중랑구)
results_중랑 = model_중랑.fit()
print(results_중랑.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                임대료(만원)   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.658
# Method:                 Least Squares   F-statistic:                          2.427e+04
# Date:                Wed, 07 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:11:16   Log-Likelihood:                     -2.1893e+06
# No. Observations:              403938   AIC:                                  4.379e+06
# Df Residuals:                  403906   BIC:                                  4.379e+06
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 모델을 사용하여 테스트 데이터 예측
y_pred_중랑구 = results_중랑.predict(x_test_중랑구)

# %%
origin = np.array(y_test_중랑구)
pred = np.array(y_pred_중랑구)

MAE =  mean_absolute_error(origin, pred)

MSE = mean_squared_error(origin, pred)

RMSE = np.sqrt(MSE)

# MSLE = mean_squared_log_error(origin, pred)

# RMSLE = np.sqrt(mean_squared_log_error(origin, pred))

R2 = r2_score(origin, pred)


print('MAE : ', MAE)
print('MSE : ', MSE)
print('RMSE : ', RMSE)
# print('MSLE : ', MSLE)
# print('RMSLE :', RMSLE)
print('R2 Score : ', R2)
# Out:
# MAE :  30.48895314898682
# MSE :  2991.790737826957
# RMSE :  54.697264445554836
# R2 Score :  0.3520626959122032

# %%
# TEST SET 결과
# Out:
# MSE :  387.9822266381187
# RMSE :  19.697264445554836
# R2 Score :  0.6581323149124
